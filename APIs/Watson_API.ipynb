# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, SentimentOptions, EntitiesOptions, KeywordsOptions

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2018-11-16',
    iam_apikey='hROMpJC1F5AjCmYKNp0A-jh-bjzGEVhlpk6tyg5Y-zf3',
    url='https://gateway-wdc.watsonplatform.net/natural-language-understanding/api'
)

# %%
response = natural_language_understanding.analyze(
    url='www.wsj.com/news/markets',
    features=Features(sentiment=SentimentOptions(targets=['stocks']))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_characters": 1536,
#     "features": 1,
#     "text_units": 1
#   },
#   "retrieved_url": "https://www.wsj.com/news/markets",
#   "language": "en",
#   "sentiment": {
#     "targets": [
#       {
#         "text": "stocks",
#         "score": -0.925061,
#         "label": "negative"
#       }
#     ],
#     "document": {
#       "label": "negative",
#       "score": -0.523017
#     }
#   }
# }

# %%
result = json.dumps(response, indent=2)

# %%
response
# Out:
# {'entities': [{'count': 1,
#    'disambiguation': {'dbpedia_resource': 'http://dbpedia.org/resource/IBM',
#     'name': 'IBM',
#     'subtype': ['SoftwareLicense',
#      'OperatingSystemDeveloper',
#      'ProcessorManufacturer',
#      'SoftwareDeveloper',
#      'CompanyFounder',
#      'ProgrammingLanguageDesigner',
#      'ProgrammingLanguageDeveloper']},
#    'relevance': 0.33,
#    'sentiment': {'label': 'neutral', 'score': 0.0},
#    'text': 'IBM',
#    'type': 'Company'}],
#  'keywords': [{'count': 1,
#    'relevance': 0.984693,
#    'sentiment': {'label': 'neutral', 'score': 0},
#    'text': 'American multinational technology company'},
#   {'count': 1,
#    'relevance': 0.854311,
#    'sentiment': {'label': 'neutral', 'score': 0},
#    'text': 'United States'}],
#  'language': 'en',
#  'usage': {'features': 2, 'text_characters': 140, 'text_units': 1}}

# %%
response['entities'][0]['sentiment']['score']
# Out:
# 0.0

# %%
with open('Complete.json') as train_f:
   data = json.load(train_f)

# %%
import numpy as np
import pandas as pd
data = pd.DataFrame(data)

# %%
data = data.drop(['sentiment'], axis=1)

# %%
idx = 0
for i in data['text']:
    if len(i) < 50:
        data.drop(data.index[idx], inplace = True)
    else:
        idx = idx + 1

# %%
test = data.values

# %%
data.reset_index().to_json(orient='records')
# Out:
# '[{"index":"0","text":"Thank you, Ellen. We have a strong 2018, with total revenues of $136.8 billion, up 23% over 2017, reflecting the benefit of our ongoing investments to deliver exceptional experiences for users and compelling returns for our advertisers, partners and enterprise customers."},{"index":"1","text":"Stock-based compensation totaled $2.3 billion. Headcount at the end of the quarter was 98,771, up 4,399 from last quarter. Consistent with prior quarters, the majority of new hires were engineers and product managers. In terms of product areas, the most sizable head count increases were in Cloud for both technical and sales roles."},{"index":"10","text":"For the full-year 2018, Other Bets revenues were $595 million, up 25% versus 2017 primarily generated by Fiber and Verily. Operating loss for Other Bets was $3.4 billion for the full-year 2018 versus an operating loss of $2.7 billion in 2017. Other Bets accrued CapEx was $181 million, down from $493 million in 2017 primarily reflecting investments in Fiber."},{"index":"100","text":"Great. Thank you. I just wanted to follow up on India, just bigger picture, Brian, do the new policies change your view at all of the attractiveness or the potential of operating in India and how do you think about your investment strategy there in the near term? And then also just hoping you could talk about some of the impact in the US and UK from free shipping during the fourth quarter holidays?"},{"index":"1001","text":"At this time, there are no further questions. Please continue with any closing remarks."},{"index":"1003","text":"Okay. Since there are no more questions, we would like to take a moment to thank everybody for joining the call. On behalf of our senior management team, we hope to see many of you in the coming months. If any additional questions arise in the meantime, please don\'t hesitate to reach out to Heather. Otherwise, enjoy the rest of your day, and we look forward to speaking with you on our first quarter call in April. Thank you."},{"index":"1006","text":"Ladies and gentlemen, this does conclude the Goldman Sachs Fourth Quarter 2018 Earnings Conference Call. Thank you for your participation. You may now disconnect."},{"index":"1008","text":"Good morning. This is Heather Miner, Head of Investor Relations at Goldman Sachs. Welcome to our fourth quarter earnings conference call. Today, we will use a new earnings presentation, which can be found on the Investor Relations page of our website at www.gs.com. No information on forward-looking statements and non-GAAP measures appear on the earnings release and presentation. [Technical Difficulty] reproduced or rebroadcast without our consent."},{"index":"1009","text":"Today on the call, I am joined by our Chairman and Chief Executive Officer, David Solomon; and our Chief Financial Officer, Stephen Scherr. As noted on the agenda on Page 1 of the presentation, David will provide introductory remarks about our strategic priorities, perspectives on the macro environment and an update on 1MDB. Then Stephen will walk through our financial performance. They\'ll be happy to take your questions after that."},{"index":"101","text":"Yeah. Really, we\'re still evaluating the situation in India. We feel very good about the long term prospects in India and doing a good job for both Indian customers and Indian sellers. The new regulations need to be interpreted, need to be -- need to make sure they don\'t have unintended consequences. And again, I don\'t think it\'s necessarily consistent with better price, better selection and better convenience for the Indian customer. So it\'s not all we can say on that topic right now."},{"index":"1012","text":"Thanks, Heather, and thanks to everyone for joining us this morning. I\'m very happy to be here with you, and I look forward to joining this call in a more regular basis. I\'m going to start off this morning by reiterating that I\'m fully committed to an active and ongoing dialogue with our ...

# %%
response = natural_language_understanding.analyze(
    text='Data_FOR_WATSON.csv',
    features=Features(
        entities=EntitiesOptions(emotion=False, sentiment=True, limit=2),
        keywords=KeywordsOptions(emotion=False, sentiment=True,
                                 limit=2))).get_result()

# %%
response
# Out:
# {'entities': [{'count': 8,
#    'disambiguation': {'dbpedia_resource': 'http://dbpedia.org/resource/Sheamus',
#     'name': 'Sheamus',
#     'subtype': []},
#    'relevance': 0.836836,
#    'sentiment': {'label': 'positive', 'score': 0.419996},
#    'text': 'Stephen Scherr',
#    'type': 'Person'},
#   {'count': 6,
#    'disambiguation': {'dbpedia_resource': 'http://dbpedia.org/resource/David',
#     'name': 'David',
#     'subtype': ['Monarch', 'OperaCharacter', 'ReligiousLeader']},
#    'relevance': 0.753868,
#    'sentiment': {'label': 'positive', 'score': 0.069674},
#    'text': 'David Solomon',
#    'type': 'Person'}],
#  'keywords': [{'count': 2,
#    'relevance': 0.583015,
#    'sentiment': {'label': 'negative', 'score': -0.619714},
#    'text': 'full-year'},
#   {'count': 6,
#    'relevance': 0.582395,
#    'sentiment': {'label': 'positive', 'score': 0.852335},
#    'text': '."},{"index'}],
#  'language': 'en',
#  'usage': {'features': 2, 'text_characters': 50000, 'text_units': 5},
#  'warnings': ['Text content exceeds 50000 character limit. Only first 50000 characters processed...']}

# %%
data
# Out:
#                                                    text
# 0     Thank you, Ellen. We have a strong 2018, with ...
# 1     Stock-based compensation totaled $2.3 billion....
# 10    For the full-year 2018, Other Bets revenues we...
# 100   Great. Thank you. I just wanted to follow up o...
# 1001  At this time, there are no further questions. ...
# 1003  Okay. Since there are no more questions, we wo...
# 1006  Ladies and gentlemen, this does conclude the G...
# 1008  Good morning. This is Heather Miner, Head of I...
# 1009  Today on the call, I am joined by our Chairman...
# 101   Yeah. Really, we're still evaluating the situa...
# 1012  Thanks, Heather, and thanks to everyone for jo...
# 1013  As shown on Page 2, it is important to undersc...
# 1014  As our strategic business reviews are progress...
# 1016  Specifically as it relates to FICC, we have a ...
# 1017  Over recent years, we've made significant prog...
# 1018  Secondly, we have a world-class alternatives i...
# 1019  Next, on cash management. As we evaluated oppo...
# 102   Yeah. And I think Doug, your second point was ...
# 1020  Lastly, as we bring markets and the business o...
# 1021  Across these and other investments for growth,...
# 1022  Before we discuss our results, I'll make a few...
# 1023  In addition for now the absolute level of acti...
# 1024  Next, I'd like to take a moment to address the...
# 1025  First, we are cooperating with the Department ...
# 1027  It's very clear that the people of Malaysia we...
# 1028  Significantly, and again as a part of our due ...
# 1029  In addition, I want to address the issue of Jh...
# 103   Thank you. Our next question comes from the li...
# 1030  In fact, before, during and after the 1MDB tra...
# 1031  With that, let's switch gears and review our p...
# ...                                                 ...
# 948   And candidly, from a competitive point of view...
# 95    Our guidance incorporates the order trends tha...
# 951   And when you think about how you get paid for ...
# 953   Sure. So I just want to be clear. When we look...
# 954   When I was referring to lending, what I was po...
# 956   Your next question is from the line of Brennan...
# 958   Curious on Marcus deposits. We've heard here i...
# 96    Our guidance also assumes, among other things,...
# 961   Sure. So I think if you look historically from...
# 963   Terrific. I appreciate that. And then for my s...
# 965   Sure. So that can go in a number of ways. I'll...
# 967   Your next question is from the line of Steven ...
# 969   So I wanted to start off with a question on so...
# 97    Great. Thank you. I guess I'll ask about units...
# 972   Sure. So thanks for the question and for the c...
# 974   Stephen, those insights are quite helpful. Jus...
# 976   [Technical Difficulty] example of that is in a...
# 978   Your next question is from the line of Jim Mit...
# 98    Yeah. Hey, Justin, this is Dave. Just on the s...
# 980   Maybe a strategy question in retail. I always ...
# 983   So as we talked about, as we think about Marcu...
# 985   Your next question is from the line of Devin R...
# 987   Great. I guess, first question here, you gave ...
# 989   Sure. So first, obviously when you want a fron...
# 99    Secondly, could you talk about advertising rev...
# 991   Well, I would just point out, I think that thi...
# 994   Good morning. My name is Dennis, and I will be...
# 995   Your next question comes from the line of Gera...
# 997   Can you guys share with us -- and I apologize ...
# 999   Sure. So what we have seen from MiFID II is re...
#
# [1119 rows x 1 columns]

# %%
score = 0 
# a = 0
for i in data['text']:
    response = natural_language_understanding.analyze(
    text= i ,
    features=Features(
        entities=EntitiesOptions(emotion=False, sentiment=True, limit=2),
        keywords=KeywordsOptions(emotion=False, sentiment=True,
                                 limit=2))).get_result()
#     print(a)
#     a += 1 

    print(json.dumps(response, indent=2))
    if response['entities']:
        score = score + response['entities'][0]['sentiment']['score']
    elif response['keywords']:
        score = score + response['keywords'][0]['sentiment']['score']
    else:
        score += 0
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 271
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.948795,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.997936
#       },
#       "text": "total revenues"
#     },
#     {
#       "count": 1,
#       "relevance": 0.874435,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.997936
#       },
#       "text": "benefit of our ongoing investments"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.926911,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.553561
#       },
#       "text": "Ellen",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.926911,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$136.8 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 332
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.808133,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.655981
#       },
#       "text": "terms of product areas"
#     },
#     {
#       "count": 1,
#       "relevance": 0.729968,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.655981
#       },
#       "text": "sizable head count increases"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$2.3 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 359
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.974552,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0,
#         "mixed": "1"
#       },
#       "text": "full-year"
#     },
#     {
#       "count": 1,
#       "relevance": 0.929999,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.489383
#       },
#       "text": "Bets revenues"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$181 million",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$2.7 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 401
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.880502,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.810443
#       },
#       "text": "bigger picture"
#     },
#     {
#       "count": 1,
#       "relevance": 0.757824,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.810443
#       },
#       "text": "new policies"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.891192,
#       "type": "Location",
#       "count": 2,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.06305
#       },
#       "disambiguation": {
#         "subtype": [
#           "Country"
#         ]
#       },
#       "text": "India"
#     },
#     {
#       "count": 1,
#       "relevance": 0.544044,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Brian",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 87
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.718754,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "closing remarks"
#     },
#     {
#       "count": 1,
#       "relevance": 0.660628,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "further questions"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 427
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.914541,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.553547
#       },
#       "text": "behalf of our senior management team"
#     },
#     {
#       "count": 1,
#       "relevance": 0.736857,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "additional questions"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 162
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.934986,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.702728
#       },
#       "text": "Goldman Sachs Fourth Quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.797664,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.702728
#       },
#       "text": "Ladies"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.924289,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "Goldman Sachs",
#         "dbpedia_resource": "http://dbpedia.org/resource/Goldman_Sachs",
#         "subtype": [
#           "CompanyShareholder"
#         ]
#       },
#       "text": "Goldman Sachs"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 451
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.844628,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.757754
#       },
#       "text": "Technical Difficulty"
#     },
#     {
#       "count": 1,
#       "relevance": 0.75197,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "Heather Miner"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.914011,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Head of Investor Relations",
#       "type": "JobTitle"
#     },
#     {
#       "count": 1,
#       "relevance": 0.756914,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Investor Relations",
#       "type": "PrintMedia"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 436
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.828867,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.927261
#       },
#       "text": "Executive Officer"
#     },
#     {
#       "count": 1,
#       "relevance": 0.795538,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.927261
#       },
#       "text": "David Solomon"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.91935,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Chairman and Chief Executive Officer",
#       "type": "JobTitle"
#     },
#     {
#       "count": 1,
#       "relevance": 0.80016,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Chief Financial Officer",
#       "type": "JobTitle"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 490
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.909054,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.998473
#       },
#       "text": "good job"
#     },
#     {
#       "count": 1,
#       "relevance": 0.815128,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "new regulations"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.770445,
#       "type": "Location",
#       "count": 2,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.719644
#       },
#       "disambiguation": {
#         "name": "India",
#         "dbpedia_resource": "http://dbpedia.org/resource/India",
#         "subtype": [
#           "HumanLanguage",
#           "Region",
#           "GovernmentalJurisdiction",
#           "FilmEditor",
#           "Country"
#         ]
#       },
#       "text": "India"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 465
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.776277,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.992147
#       },
#       "text": "Thanks"
#     },
#     {
#       "count": 1,
#       "relevance": 0.723818,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.983911
#       },
#       "text": "initial step"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.76329,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.707153
#       },
#       "text": "Heather",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 889
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.753028,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.993041
#       },
#       "text": "diverse client franchise"
#     },
#     {
#       "count": 1,
#       "relevance": 0.656404,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.993041
#       },
#       "text": "core mission"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.978456,
#       "type": "Person",
#       "count": 1,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.52969
#       },
#       "disambiguation": {
#         "name": "Sheamus",
#         "dbpedia_resource": "http://dbpedia.org/resource/Sheamus",
#         "subtype": []
#       },
#       "text": "Stephen"
#     },
#     {
#       "count": 1,
#       "relevance": 0.913262,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "John",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 663
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.847438,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.921147
#       },
#       "text": "strategic business reviews"
#     },
#     {
#       "count": 1,
#       "relevance": 0.720506,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.990431
#       },
#       "text": "significant amount of time"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 528
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.749053,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.799273
#       },
#       "text": "Bank of America Merrill Conference"
#     },
#     {
#       "count": 1,
#       "relevance": 0.621302,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.799273
#       },
#       "text": "past decade"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.976483,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Merrill Conference",
#       "type": "Organization"
#     },
#     {
#       "relevance": 0.856954,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "Bank of America",
#         "dbpedia_resource": "http://dbpedia.org/resource/Bank_of_America",
#         "subtype": []
#       },
#       "text": "Bank of America"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 566
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.929779,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.977461
#       },
#       "text": "recent years"
#     },
#     {
#       "count": 1,
#       "relevance": 0.784151,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.977461
#       },
#       "text": "capital utilization"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 603
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.798265,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.818785
#       },
#       "text": "track record"
#     },
#     {
#       "count": 1,
#       "relevance": 0.75565,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.954678
#       },
#       "text": "world-class alternatives"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.768137,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.931902
#       },
#       "text": "partner",
#       "type": "JobTitle"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 732
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.702804,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.957823
#       },
#       "text": "pace of technological change"
#     },
#     {
#       "count": 1,
#       "relevance": 0.660975,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.957823
#       },
#       "text": "payment space"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "6 months",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "2-year",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 760
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.782088,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.86499
#       },
#       "text": "number of record"
#     },
#     {
#       "count": 1,
#       "relevance": 0.695839,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.898506
#       },
#       "text": "holiday season"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.914198,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "Alexa Internet",
#         "dbpedia_resource": "http://dbpedia.org/resource/Alexa_Internet",
#         "subtype": []
#       },
#       "text": "Alexa"
#     },
#     {
#       "count": 1,
#       "relevance": 0.803128,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.660573
#       },
#       "text": "Doug",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 503
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.854201,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.822824
#       },
#       "text": "business of Investment Management"
#     },
#     {
#       "count": 1,
#       "relevance": 0.716646,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.822824
#       },
#       "text": "single product"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.968039,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Investment Management",
#       "type": "JobTitle"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 581
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.707521,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.796177
#       },
#       "text": "strategic priorities"
#     },
#     {
#       "count": 1,
#       "relevance": 0.67361,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.989255
#       },
#       "text": "significant focus"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 773
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.824895,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.286954
#       },
#       "text": "fourth quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.730038,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.957454
#       },
#       "text": "central banks"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 1051
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.739558,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.891387
#       },
#       "text": "U.S. China trade policy"
#     },
#     {
#       "count": 1,
#       "relevance": 0.724452,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.869146
#       },
#       "text": "Financial markets"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.892852,
#       "type": "Location",
#       "count": 2,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "China",
#         "dbpedia_resource": "http://dbpedia.org/resource/China",
#         "subtype": [
#           "Region",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "Kingdom",
#           "FilmScreeningVenue",
#           "Country"
#         ]
#       },
#       "text": "China"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 244
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.927384,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.668636
#       },
#       "text": "ongoing investigations"
#     },
#     {
#       "count": 1,
#       "relevance": 0.731196,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.668636
#       },
#       "text": "Malaysian sovereign development fund"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 399
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.75927,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.925671
#       },
#       "text": "important facts"
#     },
#     {
#       "count": 1,
#       "relevance": 0.756758,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.925671
#       },
#       "text": "own review of this matter"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.806234,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.433444
#       },
#       "text": "Department of Justice",
#       "type": "Organization"
#     },
#     {
#       "count": 1,
#       "relevance": 0.806234,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "3 years",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 923
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.856033,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.629333
#       },
#       "text": "Tim Leissner"
#     },
#     {
#       "count": 1,
#       "relevance": 0.736791,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "highest members of the prior government"
#     }
#   ],
#   "entities": [
#     {
#       "count": 5,
#       "relevance": 0.853466,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.507661
#       },
#       "text": "Tim Leissner",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.3559,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.546445
#       },
#       "text": "Jho Low",
#       "type": "GeographicFeature"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 527
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.940341,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.842638
#       },
#       "text": "part of our due diligence efforts"
#     },
#     {
#       "count": 2,
#       "relevance": 0.791281,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.842638
#       },
#       "text": "1MDB"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.919724,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.789318
#       },
#       "disambiguation": {
#         "name": "Goldman Sachs",
#         "dbpedia_resource": "http://dbpedia.org/resource/Goldman_Sachs",
#         "subtype": [
#           "CompanyShareholder"
#         ]
#       },
#       "text": "Goldman Sachs"
#     },
#     {
#       "relevance": 0.63272,
#       "type": "Location",
#       "count": 2,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "Country"
#         ]
#       },
#       "text": "Malaysia"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 538
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.848559,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.595696
#       },
#       "text": "issue of Jho Low"
#     },
#     {
#       "count": 1,
#       "relevance": 0.646692,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.931949
#       },
#       "text": "Jho Low's request"
#     }
#   ],
#   "entities": [
#     {
#       "count": 4,
#       "relevance": 0.911689,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.492859
#       },
#       "text": "Jho Low",
#       "type": "GeographicFeature"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 71
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.996176,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "next question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.586433,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "Citi"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.998522,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.38595
#       },
#       "disambiguation": {
#         "name": "Citigroup",
#         "dbpedia_resource": "http://dbpedia.org/resource/Citigroup",
#         "subtype": []
#       },
#       "text": "Citi"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 886
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.732605,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.501479,
#         "mixed": "1"
#       },
#       "text": "difficult time"
#     },
#     {
#       "count": 1,
#       "relevance": 0.698508,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.93574
#       },
#       "text": "important lessons"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.925459,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.324458
#       },
#       "text": "Jho Low",
#       "type": "GeographicFeature"
#     },
#     {
#       "count": 1,
#       "relevance": 0.685474,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.257072
#       },
#       "text": "Low",
#       "type": "Company"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 543
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.864916,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.998215
#       },
#       "text": "significant investments"
#     },
#     {
#       "count": 1,
#       "relevance": 0.770786,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.998215
#       },
#       "text": "long-term earnings profile of the firm"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$36.6 billion",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "8 years",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 354
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.798866,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.953469
#       },
#       "text": "solid year"
#     },
#     {
#       "count": 1,
#       "relevance": 0.664908,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.522454
#       },
#       "text": "team"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.820403,
#       "type": "Person",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "Sheamus",
#         "dbpedia_resource": "http://dbpedia.org/resource/Sheamus",
#         "subtype": []
#       },
#       "text": "Stephen"
#     },
#     {
#       "count": 1,
#       "relevance": 0.725197,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "John",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 122
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.880873,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.7985
#       },
#       "text": "details of our financial performance"
#     },
#     {
#       "count": 2,
#       "relevance": 0.700212,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.7985
#       },
#       "text": "Stephen"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.88938,
#       "type": "Person",
#       "count": 2,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.519069
#       },
#       "disambiguation": {
#         "name": "Sheamus",
#         "dbpedia_resource": "http://dbpedia.org/resource/Sheamus",
#         "subtype": []
#       },
#       "text": "Stephen"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 383
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.915471,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.280723
#       },
#       "text": "fourth quarter net revenues"
#     },
#     {
#       "count": 3,
#       "relevance": 0.759982,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.61129,
#         "mixed": "1"
#       },
#       "text": "full year"
#     }
#   ],
#   "entities": [
#     {
#       "count": 2,
#       "relevance": 0.87525,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.693872
#       },
#       "text": "David",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.87525,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$10.5 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 494
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.798376,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.737586
#       },
#       "text": "detailed discussion of our results"
#     },
#     {
#       "count": 1,
#       "relevance": 0.745207,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.735983
#       },
#       "text": "income statement"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 355
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.800823,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.776021
#       },
#       "text": "temporary staff"
#     },
#     {
#       "count": 1,
#       "relevance": 0.769841,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "bottom line"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$280 million",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 386
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.94441,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.901244
#       },
#       "text": "fourth quarter results"
#     },
#     {
#       "count": 1,
#       "relevance": 0.67578,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.430202
#       },
#       "text": "presentation of our financial statements"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$516 million",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$844 million",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 458
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.829884,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.953463
#       },
#       "text": "great quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.756921,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.953463
#       },
#       "text": "retail part of the businesses"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.820399,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "AWS",
#       "type": "Company"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 901
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.906585,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.396342
#       },
#       "text": "tax rate"
#     },
#     {
#       "count": 1,
#       "relevance": 0.852509,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.86528
#       },
#       "text": "discrete benefit"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.880139,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Treasury",
#       "type": "Organization"
#     },
#     {
#       "count": 2,
#       "relevance": 0.880139,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "16%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 500
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.920988,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.558346
#       },
#       "text": "fourth quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.779536,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.863578
#       },
#       "text": "evolving backdrop"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.784268,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "David",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 386
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.961752,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.988515
#       },
#       "text": "overall performance"
#     },
#     {
#       "count": 1,
#       "relevance": 0.838799,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.988515
#       },
#       "text": "business model"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.836437,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "5 years",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 961
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.876677,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.688713
#       },
#       "text": "fourth quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.77108,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "Investment Banking"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.887235,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.597413
#       },
#       "text": "client coverage",
#       "type": "JobTitle"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 589
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.88647,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.952026
#       },
#       "text": "high yield"
#     },
#     {
#       "count": 1,
#       "relevance": 0.804798,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.926468
#       },
#       "text": "Market volatility"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.921472,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Financial Advisory and Underwriting",
#       "type": "JobTitle"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 459
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.953786,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.998388
#       },
#       "text": "strong performance"
#     },
#     {
#       "count": 1,
#       "relevance": 0.881657,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.972599
#       },
#       "text": "Investment Banking franchise"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 986
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.777577,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.689344
#       },
#       "text": "fourth quarter"
#     },
#     {
#       "count": 2,
#       "relevance": 0.762236,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.570719
#       },
#       "text": "Net revenues"
#     }
#   ],
#   "entities": [
#     {
#       "count": 2,
#       "relevance": 0.804456,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Institutional Client Services",
#       "type": "JobTitle"
#     },
#     {
#       "relevance": 0.644179,
#       "type": "Location",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ]
#       },
#       "text": "FICC"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 451
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.926231,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "fourth quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.697964,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "FICC businesses"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.925162,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "FICC",
#       "type": "Company"
#     },
#     {
#       "count": 1,
#       "relevance": 0.421162,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.701833
#       },
#       "text": "strategic initiatives",
#       "type": "JobTitle"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 355
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.824457,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.970241
#       },
#       "text": "basis points"
#     },
#     {
#       "count": 1,
#       "relevance": 0.703412,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.741944
#       },
#       "text": "minimal top line benefit"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 436
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.795027,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.99095
#       },
#       "text": "impact factors"
#     },
#     {
#       "count": 1,
#       "relevance": 0.724656,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.99095
#       },
#       "text": "advertising accounting change"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.677884,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Whole Foods",
#       "type": "Company"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 337
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.889352,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.980617
#       },
#       "text": "better serve"
#     },
#     {
#       "count": 1,
#       "relevance": 0.760494,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.892155
#       },
#       "text": "better results"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 506
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.895747,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.962683
#       },
#       "text": "enhancements of platforms"
#     },
#     {
#       "count": 1,
#       "relevance": 0.845514,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.999247
#       },
#       "text": "new platforms"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.803682,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.465353
#       },
#       "text": "FICC",
#       "type": "Company"
#     },
#     {
#       "count": 1,
#       "relevance": 0.803682,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "40%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 579
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.837112,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.695439
#       },
#       "text": "Security services"
#     },
#     {
#       "count": 1,
#       "relevance": 0.812424,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.468498
#       },
#       "text": "Equities client execution net revenues"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.885832,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$1.6 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 504
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.957167,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.910452
#       },
#       "text": "share of global equity market volumes"
#     },
#     {
#       "count": 1,
#       "relevance": 0.736688,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.910452
#       },
#       "text": "basis points"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$7.6 billion",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "12 months",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 959
#   },
#   "keywords": [
#     {
#       "count": 3,
#       "relevance": 0.802827,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.787525
#       },
#       "text": "net revenues"
#     },
#     {
#       "count": 1,
#       "relevance": 0.792972,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.889414
#       },
#       "text": "Equity securities"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.949481,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$21.4 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 901
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.854109,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.635577
#       },
#       "text": "fourth quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.702405,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.286535,
#         "mixed": "1"
#       },
#       "text": "year-end"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$113 billion",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$2.7 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 1102
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.901718,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.774869
#       },
#       "text": "full year"
#     },
#     {
#       "count": 1,
#       "relevance": 0.791368,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "net revenues"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$1.54 trillion",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$1.4 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 637
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.695546,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.974242
#       },
#       "text": "stable efficiency ratio"
#     },
#     {
#       "count": 1,
#       "relevance": 0.675009,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.938277
#       },
#       "text": "higher level of accountability"
#     }
#   ],
#   "entities": [
#     {
#       "count": 2,
#       "relevance": 0.723455,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "John",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.649963,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Relatedly",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 378
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.947222,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.488373
#       },
#       "text": "basis points"
#     },
#     {
#       "count": 1,
#       "relevance": 0.773874,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.59261
#       },
#       "text": "like basis"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "33.7%",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "6%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 225
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.86783,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.922076
#       },
#       "text": "retail margins"
#     },
#     {
#       "count": 1,
#       "relevance": 0.785869,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.922076
#       },
#       "text": "modest hiring"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 765
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.93599,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.68452
#       },
#       "text": "operating expenses"
#     },
#     {
#       "count": 1,
#       "relevance": 0.883379,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.846715
#       },
#       "text": "Fourth quarter"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.852284,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "Goldman Sachs",
#         "dbpedia_resource": "http://dbpedia.org/resource/Goldman_Sachs",
#         "subtype": [
#           "CompanyShareholder"
#         ]
#       },
#       "text": "Goldman Sachs"
#     },
#     {
#       "count": 1,
#       "relevance": 0.852284,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$132 million",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 262
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.889822,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.467597
#       },
#       "text": "current interpretations of the rules"
#     },
#     {
#       "count": 2,
#       "relevance": 0.712924,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.467597
#       },
#       "text": "tax rate"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "16%",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "22%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 494
#   },
#   "keywords": [
#     {
#       "count": 3,
#       "relevance": 0.909428,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.682078
#       },
#       "text": "basis points"
#     },
#     {
#       "count": 1,
#       "relevance": 0.867112,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.726741
#       },
#       "text": "Common Equity Tier"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "13.1%",
#       "type": "Quantity"
#     },
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "13.3%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 375
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.954394,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.766155
#       },
#       "text": "shares of common stock"
#     },
#     {
#       "count": 1,
# ...
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 1249
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.843252,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.91945
#       },
#       "text": "perspective look"
#     },
#     {
#       "count": 1,
#       "relevance": 0.80954,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.802335
#       },
#       "text": "risk exposure"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.726704,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$2 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 73
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.99064,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "next question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.31569,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "line of Steven Chubak"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Steven Chubak",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Wolfe Research",
#       "type": "Company"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 871
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.867553,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.979763
#       },
#       "text": "interesting things"
#     },
#     {
#       "count": 1,
#       "relevance": 0.775951,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.646518
#       },
#       "text": "efficiency commentary"
#     }
#   ],
#   "entities": [
#     {
#       "count": 2,
#       "relevance": 0.961115,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.693067
#       },
#       "text": "David",
#       "type": "Person"
#     },
#     {
#       "relevance": 0.762213,
#       "type": "Person",
#       "count": 1,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.599175
#       },
#       "disambiguation": {
#         "name": "Sheamus",
#         "dbpedia_resource": "http://dbpedia.org/resource/Sheamus",
#         "subtype": []
#       },
#       "text": "Stephen"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 295
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.925808,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.958098
#       },
#       "text": "overall unit growth"
#     },
#     {
#       "count": 1,
#       "relevance": 0.80247,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.958098
#       },
#       "text": "higher last year"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "14%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 1517
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.72867,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.784267
#       },
#       "text": "basis points"
#     },
#     {
#       "count": 2,
#       "relevance": 0.699377,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.861498
#       },
#       "text": "efficiency ratio"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.732643,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.656681
#       },
#       "text": "David",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.732643,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "12%",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 580
#   },
#   "keywords": [
#     {
#       "count": 2,
#       "relevance": 0.77531,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.536266
#       },
#       "text": "marginal margin"
#     },
#     {
#       "count": 1,
#       "relevance": 0.75833,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.58882
#       },
#       "text": "half of the incremental revenue growth"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.914851,
#       "type": "Person",
#       "count": 1,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.593256
#       },
#       "disambiguation": {
#         "name": "Sheamus",
#         "dbpedia_resource": "http://dbpedia.org/resource/Sheamus",
#         "subtype": []
#       },
#       "text": "Stephen"
#     },
#     {
#       "count": 1,
#       "relevance": 0.914851,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "$2.5 billion",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 1219
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.702715,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.962505
#       },
#       "text": "Technical Difficulty"
#     },
#     {
#       "count": 1,
#       "relevance": 0.6366,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.630918
#       },
#       "text": "element of platform electronification"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.752443,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Marcus",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.654251,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "David",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 77
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.99064,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "next question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.31569,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "line of Jim Mitchell"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Jim Mitchell",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Buckingham Research",
#       "type": "Company"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 692
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.916376,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.807491
#       },
#       "text": "second question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.846434,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.807491
#       },
#       "text": "subscription services"
#     }
#   ],
#   "entities": [
#     {
#       "count": 2,
#       "relevance": 0.880199,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.710108
#       },
#       "text": "Dave",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.725895,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.759441
#       },
#       "text": "We\ufffdd",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 433
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.758574,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.892274
#       },
#       "text": "plans"
#     },
#     {
#       "count": 1,
#       "relevance": 0.63834,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.982089
#       },
#       "text": "wealth management"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.639014,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.649485
#       },
#       "text": "Goldman",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 1228
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.694228,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.980264
#       },
#       "text": "digital platform"
#     },
#     {
#       "count": 1,
#       "relevance": 0.686643,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.75437
#       },
#       "text": "lack of term"
#     }
#   ],
#   "entities": [
#     {
#       "count": 2,
#       "relevance": 0.849593,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Marcus",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 70
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.99064,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "next question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.31569,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "line of Devin Ryan"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Devin Ryan",
#       "type": "Person"
#     },
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "JMP Securities",
#       "type": "Company"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 529
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.762581,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.789754
#       },
#       "text": "first question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.691535,
#       "sentiment": {
#         "label": "negative",
#         "score": -0.789754
#       },
#       "text": "little bit of a preview"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 859
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.872297,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.756099
#       },
#       "text": "new management team"
#     },
#     {
#       "count": 1,
#       "relevance": 0.813704,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.949289
#       },
#       "text": "real purpose"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.910464,
#       "type": "Person",
#       "count": 1,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.823719
#       },
#       "disambiguation": {
#         "name": "Sheamus",
#         "dbpedia_resource": "http://dbpedia.org/resource/Sheamus",
#         "subtype": []
#       },
#       "text": "Stephen"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 290
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.83727,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "advertising revenue"
#     },
#     {
#       "count": 1,
#       "relevance": 0.619715,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.766386
#       },
#       "text": "real step"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 809
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.939831,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "elements of ops"
#     },
#     {
#       "count": 1,
#       "relevance": 0.89034,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.48603
#       },
#       "text": "risk point of view"
#     }
#   ],
#   "entities": [],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 245
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.934916,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.669054
#       },
#       "text": "Goldman Sachs Fourth Quarter"
#     },
#     {
#       "count": 1,
#       "relevance": 0.81144,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.903321
#       },
#       "text": "Good morning"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.85707,
#       "type": "Company",
#       "count": 1,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.483384
#       },
#       "disambiguation": {
#         "name": "Goldman Sachs",
#         "dbpedia_resource": "http://dbpedia.org/resource/Goldman_Sachs",
#         "subtype": [
#           "CompanyShareholder"
#         ]
#       },
#       "text": "Goldman Sachs"
#     },
#     {
#       "count": 2,
#       "relevance": 0.573251,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Dennis",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 66
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.997286,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "next question"
#     },
#     {
#       "count": 1,
#       "relevance": 0.591658,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0
#       },
#       "text": "RBC"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.33,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "Gerard Cassidy",
#       "type": "Person"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 382
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.867902,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.875726
#       },
#       "text": "good numbers"
#     },
#     {
#       "count": 1,
#       "relevance": 0.829297,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.875726
#       },
#       "text": "year growth"
#     }
#   ],
#   "entities": [
#     {
#       "count": 1,
#       "relevance": 0.01,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "text": "12 months",
#       "type": "Quantity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 806
#   },
#   "keywords": [
#     {
#       "count": 1,
#       "relevance": 0.782976,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.277584
#       },
#       "text": "market share consolidation"
#     },
#     {
#       "count": 1,
#       "relevance": 0.618774,
#       "sentiment": {
#         "label": "positive",
#         "score": 0.505279
#       },
#       "text": "consolidated share move"
#     }
#   ],
#   "entities": [
#     {
#       "relevance": 0.766201,
#       "type": "Location",
#       "count": 1,
#       "sentiment": {
#         "label": "neutral",
#         "score": 0.0
#       },
#       "disambiguation": {
#         "name": "United States",
#         "dbpedia_resource": "http://dbpedia.org/resource/United_States",
#         "subtype": [
#           "Region",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "FilmEditor",
#           "Country"
#         ]
#       },
#       "text": "U.S."
#     }
#   ],
#   "language": "en"
# }

# %%
score /= len(data)

# %%
score
# Out:
# 0.2163279311885612
